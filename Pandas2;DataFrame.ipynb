# %% [markdown]
# ## Pandas : DataFrame

# %% [markdown]
# **Create a data frame form python object**

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(101) # using seed because it give same element as show in  lecture 
mydata = np.random.randint(0,101,(4,3))

# %%
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myindex=['DL','JP','BL','MB']

# %%
mycolumn=['JAN','FEB','MAR']

# %%
df =pd.DataFrame(data=mydata,index=myindex,columns=mycolumn)

# %% [markdown]
# *here DataFrame has three parameter ,data , index/rows,columns*

# %%
df
# Out:
#     JAN  FEB  MAR
# DL   95   11   81
# JP   70   63   87
# BL   75    9   77
# MB   40    4   63

# %% [markdown]
# **DataFrame created**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, DL to MB
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   JAN     4 non-null      int32
#  1   FEB     4 non-null      int32
#  2   MAR     4 non-null      int32
# dtypes: int32(3)
# memory usage: 80.0+ bytes

# %% [markdown]
# **Read the data from existing csv file**

# %%
pwd # here is our python code is located
# Out:
# 'D:\\python\\notebooks\\machine learning course\\Pandas'

# %% [markdown]
# *pwd : print working directory*

# %%
 ls #list the files in  current directory
# Out:
# File Not Found
#  Volume in drive D is New Volume
#  Volume Serial Number is 0CC9-71A4
#
#  Directory of D:\python\notebooks\machine learning course\Pandas
#
#
#  Directory of D:\python\notebooks\machine learning course\Pandas
#
#
#  Directory of D:\python\notebooks\machine learning course\Pandas
#
#
#  Directory of D:\python\notebooks\machine learning course\Pandas
#
#
#  Directory of D:\python\notebooks\machine learning course\Pandas
#
#
#  Directory of D:\python\notebooks\machine learning course\Pandas

# %% [markdown]
# *method 1*

# %%
df =pd.read_csv("D:/python/notebooks/machine learning course/tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# *provide full file path to read_csv*

# %% [markdown]
# *first we have to understand the elements like rows and columns of dataframe df*

# %%
df.columns # show the columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index  # show the index  ,here the index is autocreated
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head(10) # reports the first five  or n rows of df according to input head(no.of rows)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# ...

# %%
df.tail() # report back last rows of df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df.info() # provide information or meta data about df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %% [markdown]
# *provide statical values for the dataframe*

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %% [markdown]
# # Columns

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# **grabing the columns**

# %%
df['total_bill'] # single column
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
type(df['total_bill'])
# Out:
# pandas.core.series.Series

# %%
df[['total_bill' ,'size']] # grabbing multiple columns
# Out:
#      total_bill  size
# 0         16.99     2
# 1         10.34     3
# 2         21.01     3
# 3         23.68     2
# 4         24.59     4
# ..          ...   ...
# 239       29.03     3
# 240       27.18     2
# 241       22.67     2
# 242       17.82     2
# 243       18.78     2
#
# [244 rows x 2 columns]

# %% [markdown]
# **Create a new columns using existing columns**

# %%
df['tip']+df['total_bill']
# Out:
# 0      18.00
# 1      12.00
# 2      24.51
# 3      26.99
# 4      28.20
#        ...
# 239    34.95
# 240    29.18
# 241    24.67
# 242    19.57
# 243    21.78
# Length: 244, dtype: float64

# %%
df['tip']/df['total_bill']
# Out:
# 0      0.059447
# 1      0.160542
# 2      0.166587
# 3      0.139780
# 4      0.146808
#          ...
# 239    0.203927
# 240    0.073584
# 241    0.088222
# 242    0.098204
# 243    0.159744
# Length: 244, dtype: float64

# %%
100*df['tip']/df['total_bill']
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
#          ...
# 239    20.392697
# 240     7.358352
# 241     8.822232
# 242     9.820426
# 243    15.974441
# Length: 244, dtype: float64

# %%
df['tip_percentage']= df['tip']+df['total_bill']

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959           18.00
# 1      Douglas Tucker  4478071379779230    Sun4608           12.00
# 2      Travis Walters  6011812112971322    Sun4458           24.51
# 3    Nathaniel Harris  4676137647685994    Sun5260           26.99
# 4        Tonya Carter  4832732618637221    Sun2251           28.20

# %%
df['price_per_person'] = df['total_bill']/df['size']

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2          8.495000
# 1         10.34  1.66    Male     No   Sun  Dinner     3          3.446667
# 2         21.01  3.50    Male     No   Sun  Dinner     3          7.003333
# 3         23.68  3.31    Male     No   Sun  Dinner     2         11.840000
# 4         24.59  3.61  Female     No   Sun  Dinner     4          6.147500
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3          9.676667
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         13.590000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         11.335000
# 242       17.82  1.75    Male     No   Sat  Dinner     2          8.910000
# 243       18.78  3.00  Female     No  Thur  Dinner     2          9.390000
#
#              Payer Name         CC Number Payment ID  tip_percentage
# ...

# %% [markdown]
# **if we run operation on existin columnn then pandas will overwrite on existing columnn, by  not creating a new column**

# %%
np.round
# Out:
# <function round at 0x000001902FBD28F0>

# %%
df['price_per_person'] = np.round(df['total_bill']/df['size'])

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2               8.0
# 1         10.34  1.66    Male     No   Sun  Dinner     3               3.0
# 2         21.01  3.50    Male     No   Sun  Dinner     3               7.0
# 3         23.68  3.31    Male     No   Sun  Dinner     2              12.0
# 4         24.59  3.61  Female     No   Sun  Dinner     4               6.0
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              10.0
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2              14.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2              11.0
# 242       17.82  1.75    Male     No   Sat  Dinner     2               9.0
# 243       18.78  3.00  Female     No  Thur  Dinner     2               9.0
#
#              Payer Name         CC Number Payment ID  tip_percentage
# ...

# %% [markdown]
# **Removing Columns**

# %%
df.drop('tip_percentage',axis=1) # we have to provide axis in order to delete form column
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2               8.0
# 1         10.34  1.66    Male     No   Sun  Dinner     3               3.0
# 2         21.01  3.50    Male     No   Sun  Dinner     3               7.0
# 3         23.68  3.31    Male     No   Sun  Dinner     2              12.0
# 4         24.59  3.61  Female     No   Sun  Dinner     4               6.0
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              10.0
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2              14.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2              11.0
# 242       17.82  1.75    Male     No   Sat  Dinner     2               9.0
# 243       18.78  3.00  Female     No  Thur  Dinner     2               9.0
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# **It actual dont delete Column  form atual data set if we dont assing to df it will only provide the output**

# %%
df=df.drop('tip_percentage',axis=1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2               8.0
# 1         10.34  1.66    Male     No   Sun  Dinner     3               3.0
# 2         21.01  3.50    Male     No   Sun  Dinner     3               7.0
# 3         23.68  3.31    Male     No   Sun  Dinner     2              12.0
# 4         24.59  3.61  Female     No   Sun  Dinner     4               6.0
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              10.0
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2              14.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2              11.0
# 242       17.82  1.75    Male     No   Sat  Dinner     2               9.0
# 243       18.78  3.00  Female     No  Thur  Dinner     2               9.0
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# **Here we assign it to actual dataframe so that atual dataframe get effected permanentaley**

# %% [markdown]
# # Index/rows

# %%
df.index # give range index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %% [markdown]
# **set columns as index**

# %%
df.set_index("Payment ID")
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                  8.0  Christy Cunningham  3560325168603410
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %% [markdown]
# **here Payment Id is set to Index now their only ten Columns available instde of 11**

# %% [markdown]
# **Note : this change is not permanet it do not assign to istsef**

# %%
df =df.set_index("Payment ID")

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                  8.0  Christy Cunningham  3560325168603410
# ...

# %% [markdown]
# **now the change is permenant**

# %%
df.iloc[0] # grabbing the first row using index
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                   8.0
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df.loc['Sun2959']# grabbing row using label index in form of series
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                   8.0
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df.loc[['Sun2959','Sun4608']]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                  8.0  Christy Cunningham  3560325168603410
# Sun4608                  3.0      Douglas Tucker  4478071379779230

# %% [markdown]
# **Removing Row**

# %%
df.drop('Sun4608',axis =0)
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                  8.0  Christy Cunningham  3560325168603410
# ...

# %% [markdown]
# **like column it is not permantent uless we dont reassign to datframe**

# %%
df = df.drop('Sun4608',axis =0)# we have to provide actual lable to drop the rows instide of using numeric index

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                  8.0  Christy Cunningham  3560325168603410
# Sun4458                  7.0      Travis Walters  6011812112971322
# Sun5260                 12.0    Nathaniel Harris  4676137647685994
# Sun2251                  6.0        Tonya Carter  4832732618637221
# Sun9679                  6.0          Erik Smith   213140353657882

# %% [markdown]
# **inserting a new row**

# %%
one_row = df.iloc[0]

# %%
one_row
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                   8.0
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df=df.append(one_row)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4192\711828457.py in ?()
# ----> 1 df=df.append(one_row)
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
